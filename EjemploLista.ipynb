# %% [markdown]
# Convertir una lista a string

# %%
lista_vocales = ["a","e","i","o","u"]
vocales_str = "".join(lista_vocales)
print(vocales_str)
# Out:
# Running cells with '.venv (Python 3.11.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/usuario/python-gkc/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
